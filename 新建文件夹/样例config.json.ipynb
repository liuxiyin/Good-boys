# %%
# {
# 	"type": "0",
#   // 组件类型 0：输入框 1：文件上传 2：日期时间选择器  3：密码框
# 4：下拉框  5：文本
# 	"cname": "登陆账号",  // 中文名
# 	"label": "username",  // 字段名
# 	"description": "请输入店铺登陆账号",  // 提示信息
# 	"value": "",  // 默认值 
# 	"rule": "True",  // 是否必填
# 	"templatePath": ""  // 模板地址
# 	"options": "[{  // 下拉框出现options
#           value: "1",
#           label: "选项1"
#         },{
#           value: "2",
#           label: "选项2"
#         }]",
# 	"regular": "/^([A-Za-z0-9_\-\.])+\@([A-Za-z0-9_\-\.])+\.([A-Za-z]{2,4})$/"  // 正则表达式

# }
[
    {
    "cname": "上传文件",
    "label": "updata",
    "type": "1",
    "value": "",
    "description": "请上传文件"
    },
    {
    "cname": "开始时间",
    "label": "start_time",
    "type": "0",
    "value": "",
    "description": "请输入日期（2021-11-01）"
    },
    {
    "cname": "结束时间",
    "label": "end_time",
    "type": "0",
    "value": "",
    "description": "请输入日期（2021-11-30）"
    }
]

# %%
{
	"type": "0",
  // 组件类型 0：输入框 1：文件上传 2：日期时间选择器  3：密码框
4：下拉框  5：文本
	"cname": "登陆账号",  // 中文名
	"label": "username",  // 字段名
	"description": "请输入店铺登陆账号",  // 提示信息
	"value": "",  // 默认值 
	"rule": "True",  // 是否必填
	"templatePath": ""  // 模板地址
	"options": "[{  // 下拉框出现options
          value: "1",
          label: "选项1"
        },{
          value: "2",
          label: "选项2"
        }]",
	"regular": "/^([A-Za-z0-9_\-\.])+\@([A-Za-z0-9_\-\.])+\.([A-Za-z]{2,4})$/"  // 正则表达式

}
交互组件类型：
组件类型  type:
0：输入框 
1：文件上传 
2：日期时间选择器
3：密码框
4：下拉框
5：文本
